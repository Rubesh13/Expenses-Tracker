# %%
# %run main.py
# Out:
# Enter DB password:  Rubesh@2007
# =====Expenses Tracker=====
#
# 1.Add User
# 2.Add Expenses
# 3.Update expenses
# 4.View Summary
# 5.Expenses Summary
# 6.Export CSV File
# 7.EXIT
# Enter your choice:  4
# Expenses:
# (20, 1, 'sundry expenses', 211, 'CASH')
# (21, 2, 'miscellaneous expenses', 1050, 'GPAY')
# (22, 3, 'education expenses', 2640, 'CARD')
# (23, 4, 'education expenses', 5000, 'CASH')
# (24, 5, 'office use', 7000, 'GPAY')
# (25, 6, 'machinery purchase', 20000, 'CARD')
# Total Expenses = 35901
#
# =====Expenses Tracker=====
#
# 1.Add User
# 2.Add Expenses
# 3.Update expenses
# 4.View Summary
# 5.Expenses Summary
# 6.Export CSV File
# 7.EXIT
